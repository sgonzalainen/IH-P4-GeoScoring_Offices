# %%
from dotenv import load_dotenv
import src.query as query
import src.folium as fl
import src.data as dt
from pymongo import GEOSPHERE
import pandas as pd
import os
from src.variables import Variables as Var
from pymongo import MongoClient
import src.stakeholders as sh

from datetime import datetime

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
load_dotenv('.env')
# Out:
# True

# %% [markdown]
# # Connection to MongoDB database and Collection creation

# %%
conn = MongoClient("localhost:27017")
db = conn.get_database("ironhack")

# %% [markdown]
# * `offices` is a collection created for coworking spaces, i.e. location candidates.
#
# * `helsinki_places` is a collection to save all the places queried.

# %%
offices = db['offices']

# %%
helsinki_places = db['helsinki_places']

# %% [markdown]
# # Data collection

# %% [markdown]
# ### Load token for foursqueare and Google APIs

# %%
client_id = os.getenv("FOURSQUARE_CLIENT_ID")
client_secret = os.getenv("FOURSQUARE_CLIENT_SECRET")

# %%
google_api = os.getenv("GOOGLE_PLACES")

# %% [markdown]
# ### Establish candidates

# %% [markdown]
# These are the coordinates for our selected city: **Helsinki**

# %%
city_lat = Var.CITY_LAT
city_lon =  Var.CITY_LON
radius = Var.RADIUS

# %% [markdown]
# All coworking spaces as list of initial candidates

# %%
data_office = query.foursquare_query(city_lat, city_lon, 'coworking_space', radius, client_id, client_secret)

# %%
candidates = dt.read_foursquare_response(data_office, 'coworking_space')

# %% [markdown]
# Let's insert them to our brand new collection in MongoDb

# %%
x = offices.insert_many(candidates)

# %%
offices.find_one()
# Out:
# {'_id': ObjectId('5fafe7f65143de9ede25a204'),
#  'type': 'coworking_space',
#  'name': 'Tiedekulma / Think Corner',
#  'location': {'coordinates': [24.948465, 60.169746], 'type': 'Point'}}

# %% [markdown]
# Let's create the Point for each office

# %%
offices.create_index([('location', GEOSPHERE)])
# Out:
# 'location_2dsphere'

# %% [markdown]
# Now, let's plot the candidates to get a picture of their locations

# %%
map_candidates = fl.create_map(city_lat, city_lon)

# %%
for candidate in candidates:
    lat = candidate['location']['coordinates'][1]
    lon = candidate['location']['coordinates'][0]
    
    fl.add_marker_icon(map_candidates, lat, lon, 'red','building','white',candidate['name'])

# %%
map_candidates
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Venus Search

# %% [markdown]
# #### Start-up Tech Companies

# %% [markdown]
# Search via Foursquare API

# %%
data_tech = query.foursquare_query(city_lat, city_lon, 'tech_startup', radius, client_id, client_secret)

# %% [markdown]
# Get a list of companies

# %%
tech_companies_list = dt.read_foursquare_response(data_tech, 'tech_startup')

# %% [markdown]
# Insert those documents in our collection `helsinki_places`

# %%
x = helsinki_places.insert_many(tech_companies_list)

# %% [markdown]
# And create index for GeoJson

# %%
helsinki_places.create_index([('location', GEOSPHERE)])
# Out:
# 'location_2dsphere'

# %% [markdown]
# Now, let's find matches for each candidate and add to `offices` number of matches.

# %%
dt.find_matches_points(offices, helsinki_places, Var.TECH_COMP, 'tech_startup')

# %% [markdown]
# #### Starbucks

# %% [markdown]
# Search via Google Places API, using 'Find Place' which returns only one match.
#
# for all candidates, we perform a query to find nearest Starbucks and get unique matches in a list.

# %%
starbucks_list = dt.find_all_google_places(offices, 'Starbucks', 50, google_api)

# %% [markdown]
# List of places is inserted to collection

# %%
x = helsinki_places.insert_many(starbucks_list)
helsinki_places.create_index([('location', GEOSPHERE)])

# %% [markdown]
# And now perform matches based on distance defined in variables.py

# %%
dt.find_matches_points(offices, helsinki_places, Var.STARBUCKS_DISTANCE, 'Starbucks')

# %% [markdown]
# #### Preschool places

# %% [markdown]
# Search via Foursquare API. Similar approach as for finding tech companies.

# %%
preschool_data = query.foursquare_query(city_lat, city_lon, 'preschool', radius, client_id, client_secret)

# %%
preschools_list = dt.read_foursquare_response(preschool_data, 'preschools')
x = helsinki_places.insert_many(preschools_list)
dt.find_matches_points(offices, helsinki_places, Var.PRESCHOOL_DISTANCE, 'preschools')

# %% [markdown]
# #### Night-clubs

# %% [markdown]
# Search via Foursquare API. Similar approach as for finding tech companies.

# %%
disco_data = query.foursquare_query(city_lat, city_lon, 'night_club', radius, client_id, client_secret)

# %%
disco_list = dt.read_foursquare_response(disco_data, 'night_club')
x = helsinki_places.insert_many(disco_list)
dt.find_matches_points(offices, helsinki_places, Var.DISCO_DISTANCE, 'night_club')

# %% [markdown]
# #### Design Studios

# %% [markdown]
# Search via Google Places API. Similar approach as for finding Starbucks.

# %%
design_com_list = dt.find_all_google_places(offices, 'Design company', 300, google_api)

# %%
x = helsinki_places.insert_many(design_com_list)
helsinki_places.create_index([('location', GEOSPHERE)])
# Out:
# 'location_2dsphere'

# %%
dt.find_matches_points(offices, helsinki_places, Var.STARBUCKS_DISTANCE, 'Design company')

# %% [markdown]
# #### Vegan Restaurants

# %% [markdown]
# Search via Foursquare API. Similar approach as for finding tech companies.

# %%
vegan_data = query.foursquare_query(city_lat, city_lon, 'vegan_rest', radius, client_id, client_secret)

# %%
vegan_list = dt.read_foursquare_response(vegan_data, 'vegan_rest')
x = helsinki_places.insert_many(vegan_list)
dt.find_matches_points(offices, helsinki_places, Var.VEGAN_DISTANCE, 'vegan_rest')

# %% [markdown]
# #### Pet Groomers

# %% [markdown]
# Search via Foursquare API. Similar approach as for finding tech companies.

# %%
pet_groomer_list = dt.find_all_google_places(offices, 'pet groomer', 50, google_api)

# %%
x = helsinki_places.insert_many(pet_groomer_list)
helsinki_places.create_index([('location', GEOSPHERE)])
dt.find_matches_points(offices, helsinki_places, Var.PET_GROOMER_DISTANCE, 'pet groomer')

# %% [markdown]
# #### Basketball stadiums

# %% [markdown]
# Search via Foursquare API. Similar approach as for finding tech companies.

# %%
basket_data = query.foursquare_query(city_lat, city_lon, 'basket_stadium', radius, client_id, client_secret)

# %%
basket_list = dt.read_foursquare_response(basket_data, 'basket_stadium')
x = helsinki_places.insert_many(basket_list)
dt.find_matches_points(offices, helsinki_places, Var.BASKET_STADIUM_DISTANCE, 'basket_stadium')

# %% [markdown]
# #### Travel to Airport

# %% [markdown]
# Search via Google Maps API

# %% [markdown]
# For each candidate, it is queried time travel from the coworking space location to Helsinki-Vantaa Airport, both by driving and by public transport.

# %% [markdown]
# For uniform time travels, travel route is queried for a regular weekday with arrival time at 12:00. As per API request, arrival time is needed to be input as seconds since 1st Jan 1970.

# %%
time = query.get_time_for_google(Var.TIME_CALC_YEAR, Var.TIME_CALC_MONTH, Var.TIME_CALC_HOUR, Var.TIME_CALC_DAY)

dt.get_travel_time(offices, Var.AIRPORT_LAT, Var.AIRPORT_LON, google_api, time)

# %% [markdown]
# ## Summary

# %%
df = pd.DataFrame(offices.find({}))

# %%
df
# Out:
#                          _id             type                       name  \
# 0   5fafe7f65143de9ede25a204  coworking_space  Tiedekulma / Think Corner
# 1   5fafe7f65143de9ede25a205  coworking_space          Spalt PR Helsinki
# 2   5fafe7f65143de9ede25a206  coworking_space              Svensk Ungdom
# 3   5fafe7f65143de9ede25a207  coworking_space                  p2s Media
# 4   5fafe7f65143de9ede25a208  coworking_space              E28 Community
# ..                       ...              ...                        ...
# 64  5fafe7f65143de9ede25a244  coworking_space                Talent Base
# 65  5fafe7f65143de9ede25a245  coworking_space                 Hippostalo
# 66  5fafe7f65143de9ede25a246  coworking_space      Nuortenosasto Pointti
# 67  5fafe7f65143de9ede25a247  coworking_space         Ahti Business Park
# 68  5fafe7f65143de9ede25a248  coworking_space              Playmysong HQ
#
#                                              location  tech_startup  \
# 0   {'coordinates': [24.948465, 60.169746], 'type'...            26
# 1   {'coordinates': [24.95028953736944, 60.1678398...            26
# 2   {'coordinates': [24.936771228051832, 60.169065...            33
# 3   {'coordinates': [24.93465212805861, 60.1656326...            36
# 4   {'coordinates': [24.931665377499726, 60.165782...            33
# ..                                                ...           ...
# 64  {'coordinates': [24.804944, 60.189072], 'type'...             2
# 65  {'coordinates': [24.811269988660655, 60.224374...             1
# 66  {'coordinates': [24.80919823050499, 60.2178988...             1
# 67  {'coordinates': [24.774798229336735, 60.166870...             0
# 68  {'coordinates': [24.92882944262788, 60.1658070...            31
#
#     Starbucks  preschools  night_club  vegan_rest  pet groomer  \
# 0           0           1          11           2            0
# 1           0           0           7           4            0
# 2           1           0          28           6            0
# 3           0           0          13           4            1
# 4           0           1          12           1            1
# ..        ...         ...         ...         ...          ...
# 64          0           0           0           0            0
# 65          0           0           1           0            1
# 66          0           0           1           0            0
# 67          0           0           0           0            0
# 68          0           1          11           0            1
#
#     basket_stadium  driving  transit  Design company
# 0                6     26.3     35.0               0
# 1                5     27.2     39.0               0
# 2                6     28.3     33.8               0
# 3                5     28.8     42.5               1
# 4                5     28.1     47.4               1
# ..             ...      ...      ...             ...
# 64               5     22.3     65.0               0
# 65               4     17.7     44.1               0
# 66               4     20.1     42.1               0
# 67               3     26.2     72.6               0
# 68               5     27.9     47.0               0
#
# [69 rows x 14 columns]

# %%
df_places = pd.DataFrame(helsinki_places.find({}))

# %%
df_places
# Out:
#                           _id            type                           name  \
# 0    5fafe8175143de9ede25a249    tech_startup                      Meetin.gs
# 1    5fafe8175143de9ede25a24a    tech_startup                    Osuma.fi HQ
# 2    5fafe8175143de9ede25a24b    tech_startup                 Online Revenue
# 3    5fafe8175143de9ede25a24c    tech_startup       Helsinki Open Device Lab
# 4    5fafe8175143de9ede25a24d    tech_startup                      Kompozure
# ..                        ...             ...                            ...
# 221  5fb021bd5143de9ede25a37e  Design company  Alfons Helsinki Design Studio
# 222  5fb021bd5143de9ede25a37f  Design company                Suomi Design Oy
# 223  5fb021bd5143de9ede25a380  Design company       Friday Digital Design Oy
# 224  5fb021bd5143de9ede25a381  Design company       Studio Ville Kokkonen Oy
# 225  5fb021bd5143de9ede25a382  Design company                 Palo Design Oy
#
#                                               location  \
# 0    {'coordinates': [24.932639703932836, 60.168104...
# 1    {'coordinates': [24.936691031806237, 60.169992...
# 2    {'coordinates': [24.9320125579834, 60.16793430...
# 3    {'coordinates': [24.939072132110592, 60.167037...
# 4    {'coordinates': [24.940059185028073, 60.168532...
# ..                                                 ...
# 221  {'coordinates': [24.9473763, 60.1841634], 'typ...
# 222  {'coordinates': [24.9645638, 60.16785729999999...
# 223  {'coordinates': [24.9683598, 60.1888519], 'typ...
# 224  {'coordinates': [24.927354, 60.19810159999999]...
# 225  {'coordinates': [24.9422431, 60.1607046], 'typ...
#
#                         place_id
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 221  ChIJn2ShT7YLkkYRGscRy-aCaEQ
# 222  ChIJV0G-l44LkkYRuS0fOrIo6mE
# 223  ChIJN-_Z7XsJkkYRtS1qz1upOrw
# 224  ChIJkX-0NYwJkkYRSrdrZii3iPc
# 225  ChIJedWvLbYLkkYR1kfeEOM7hiw
#
# [226 rows x 5 columns]

# %% [markdown]
# Backup saving

# %%
df.to_csv('data/backup.csv', index=False)

# %% [markdown]
# # Scoring and Sorting

# %% [markdown]
# Now, let's find the best suitable coworking space.

# %% [markdown]
# First, let's create our collection of stakeholders, i.e. the employees plus the office dog.

# %%
stakeholders = []

# %%
number_stakeholders ={'Ceo': 1, 'Executive': 10, 'Account': 20, 'Developer': 15, 'Engineer': 20, 'Designer': 20, 'Bluecollar': 1, 'Dog': 1}

# %%
for key, value in number_stakeholders.items():
    for _ in range(value):
        
        if key == 'Ceo':
            tmp = sh.Ceo()
        elif key == 'Executive':
            tmp = sh.Executive()
        elif key == 'Account':
            tmp = sh.Account()
        elif key == 'Developer':
            tmp = sh.Developer()
        elif key == 'Engineer':
            tmp = sh.Engineer()
        elif key == 'Designer':
            tmp = sh.Designer()
        elif key == 'Bluecollar':
            tmp = sh.Bluecollar()
        elif key == 'Dog':
            tmp = sh.Dog()
  
        stakeholders.append(tmp)

# %% [markdown]
# Now let's assign a child to 30% of employees, i.e. 26 persons approx.

# %%
stakeholders = sh.assign_child(stakeholders, Var.PARENTS_CHILD)

# %%
def get_score(stakeholders, param):
    score = 0
    for stakeholder in stakeholders:
        
        if param == 'design':
            cond = stakeholder.like_design
        elif param == 'school':
            cond = stakeholder.has_child
        elif param == 'tech':
            cond = stakeholder.like_tech
        elif param == 'starbucks':
            cond = stakeholder.like_starbucks
        elif param == 'airport':
            cond = stakeholder.need_travel
        elif param == 'club':
            cond = stakeholder.like_party
        elif param == 'vegan':
            cond = stakeholder.is_vegan
        elif param == 'basket':
            cond = stakeholder.like_basket
        elif param == 'dog':
            cond = stakeholder.need_groomer
            
        else:
            pass

        if cond:
            score += stakeholder.score
        else:
            pass
        
    return score

# %%
def score_travel(row, ideal_car, ideal_transport, red, stakeholders):
    
    car_time = row['driving']
    transport_time = row['transit']
    
    score_total = get_score(stakeholders, 'airport')
    
    penalty = 0
    
    if car_time > ideal_car:
        penalty += (car_time - ideal_car) * red
   
    else:
        pass
    
    if transport_time > ideal_transport:
        penalty += (transport_time - ideal_transport) * red
 
    else:
        pass

    

    score = score_total * (1- penalty)
    
    
    
    return score

# %%
df_score = df[['_id','name', 'location']].copy()

# %%
df_score['design_score'] = df['Design company'].apply(lambda x: get_score(stakeholders,'design') if x > 0 else 0)

# %%
df_score['school_score'] = df['preschools'].apply(lambda x: get_score(stakeholders,'school') if x > 0 else 0)

# %%
threshold = df.tech_startup.quantile(0.75)

# %%
df_score['tech_score'] = df['tech_startup'].apply(lambda x: get_score(stakeholders,'tech') if x >= threshold else 0)

# %%
df_score['starbucks_score'] = df['Starbucks'].apply(lambda x: get_score(stakeholders,'starbucks') if x > 0 else 0)

# %%
df_score['airport_score'] = df.apply(lambda x: score_travel(x,Var.IDEAL_TIME_CAR, Var.IDEAL_TIME_TRANSPORT,Var.PRC_PEN_MIN,stakeholders), axis = 1)

# %%
df_score['party_score'] = df['night_club'].apply(lambda x: get_score(stakeholders,'club') if x > 0 else 0)

# %%
df_score['vegan_score'] = df['vegan_rest'].apply(lambda x: get_score(stakeholders,'vegan') if x > 0 else 0)

# %%
df_score['basket_score'] = df['basket_stadium'].apply(lambda x: get_score(stakeholders,'basket') if x > 0 else 0)

# %%
df_score['dog_score'] = df['pet groomer'].apply(lambda x: get_score(stakeholders,'dog') if x > 0 else 0)

# %%
df_score['total'] = df_score['design_score']+df_score['school_score']+df_score['tech_score']+df_score['starbucks_score']+df_score['airport_score']+df_score['party_score']+df_score['vegan_score']+df_score['basket_score']+df_score['dog_score']

# %%
df_score = df_score.sort_values('total', ascending = False)

# %%
df_score
# Out:
#                          _id                name  \
# 10  5fafe7f65143de9ede25a20e           Epicenter
# 27  5fafe7f65143de9ede25a21f  Terveystalo Piazza
# 28  5fafe7f65143de9ede25a220        Four Reasons
# 4   5fafe7f65143de9ede25a208       E28 Community
# 7   5fafe7f65143de9ede25a20b               Boksi
# ..                       ...                 ...
# 64  5fafe7f65143de9ede25a244         Talent Base
# 39  5fafe7f65143de9ede25a22b   Portti C / Gate C
# 41  5fafe7f65143de9ede25a22d         Eckerö Line
# 58  5fafe7f65143de9ede25a23e         Moonsoft Oy
# 67  5fafe7f65143de9ede25a247  Ahti Business Park
#
#                                              location  design_score  \
# 10  {'coordinates': [24.94577562322455, 60.1698553...             0
# 27  {'coordinates': [24.930631, 60.169916], 'type'...             0
# 28  {'coordinates': [24.929534196853634, 60.168788...             0
# 4   {'coordinates': [24.931665377499726, 60.165782...           300
# 7   {'coordinates': [24.93095672646299, 60.1650659...           300
# ..                                                ...           ...
# 64  {'coordinates': [24.804944, 60.189072], 'type'...             0
# 39  {'coordinates': [24.92115325198633, 60.1545962...             0
# 41  {'coordinates': [24.920848013578677, 60.154510...             0
# 58  {'coordinates': [24.820141111789763, 60.179604...             0
# 67  {'coordinates': [24.774798229336735, 60.166870...             0
#
#     school_score  tech_score  starbucks_score  airport_score  party_score  \
# 10           630         225              500          433.0         1935
# 27           630         225              500          401.0         1935
# 28           630         225              500          392.0         1935
# 4            630         225                0          345.0         1935
# 7            630         225                0          311.0         1935
# ..           ...         ...              ...            ...          ...
# 64             0           0                0          227.0            0
# 39             0           0                0          226.0            0
# 41             0           0                0          224.0            0
# 58             0           0                0          191.0            0
# 67             0           0                0          112.0            0
#
#     vegan_score  basket_score  dog_score   total
# 10          100            10          0  3833.0
# 27          100            10          0  3801.0
# 28          100            10          5  3797.0
# 4           100            10          5  3550.0
# 7           100            10          5  3516.0
# ..          ...           ...        ...     ...
# 64            0            10          0   237.0
# 39            0            10          0   236.0
# 41            0            10          0   234.0
# 58            0            10          0   201.0
# 67            0            10          0   122.0
#
# [69 rows x 13 columns]

# %%
winner_id
# Out:
# '5fafe7f65143de9ede25a20e'

# %%
winner_id = str(df_score['_id'].head(1).iloc[0])

# %%
offices.find_one({'_id':ObjectId(winner_id)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-407-fd41aae19f4f> in <module>
# ----> 1 offices.find_one({'_id':ObjectId(winner_id)})
#
# NameError: name 'ObjectId' is not defined

# %%
offices.find_one({})
# Out:
# {'_id': ObjectId('5fafe7f65143de9ede25a204'),
#  'type': 'coworking_space',
#  'name': 'Tiedekulma / Think Corner',
#  'location': {'coordinates': [24.948465, 60.169746], 'type': 'Point'},
#  'tech_startup': 26,
#  'Starbucks': 0,
#  'preschools': 1,
#  'night_club': 11,
#  'vegan_rest': 2,
#  'pet groomer': 0,
#  'basket_stadium': 6,
#  'driving': 26.3,
#  'transit': 35.0,
#  'Design company': 0}

# %%
df.describe()
# Out:
#        tech_startup  Starbucks  preschools  night_club  vegan_rest  \
# count     69.000000  69.000000   69.000000   69.000000   69.000000
# mean      12.173913   0.072464    0.550725    4.217391    0.826087
# std       12.074471   0.261154    0.697395    6.803696    1.282880
# min        0.000000   0.000000    0.000000    0.000000    0.000000
# 25%        2.000000   0.000000    0.000000    0.000000    0.000000
# 50%        6.000000   0.000000    0.000000    0.000000    0.000000
# 75%       24.000000   0.000000    1.000000    7.000000    1.000000
# max       36.000000   1.000000    2.000000   28.000000    6.000000
#
#        pet groomer  basket_stadium    driving    transit  Design company
# count    69.000000       69.000000  69.000000  69.000000       69.000000
# mean      0.405797        5.231884  24.315942  47.289855        0.130435
# std       0.810208        0.710114   4.336291  10.007485        0.339248
# min       0.000000        3.000000  14.000000  25.800000        0.000000
# 25%       0.000000        5.000000  21.200000  40.800000        0.000000
# 50%       0.000000        5.000000  25.500000  47.400000        0.000000
# 75%       1.000000        6.000000  27.200000  54.500000        0.000000
# max       3.000000        6.000000  30.800000  72.600000        1.000000

# %%
df['_id']
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __repr__(self)
#    1363         show_dimensions = get_option("display.show_dimensions")
#    1364
# -> 1365         self.to_string(
#    1366             buf=buf,
#    1367             name=self.name,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1435             max_rows=max_rows,
#    1436         )
# -> 1437         result = formatter.to_string()
#    1438
#    1439         # catch contract violations
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_string(self)
#     357
#     358         fmt_index, have_header = self._get_formatted_index()
# --> 359         fmt_values = self._get_formatted_values()
#     360
#     361         if self.truncate_v:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _get_formatted_values(self)
#     340
#     341     def _get_formatted_values(self) -> List[str]:
# --> 342         return format_array(
#     343             self.tr_series._values,
#     344             None,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1170     )
#    1171
# -> 1172     return fmt_obj.get_result()
#    1173
#    1174
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in get_result(self)
#    1201
#    1202     def get_result(self) -> List[str]:
# -> 1203         fmt_values = self._format_strings()
#    1204         return _make_fixed_width(fmt_values, self.justify)
#    1205
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _format_strings(self)
#    1266                 else:
#    1267                     tpl = " {v}"
# -> 1268                 fmt_values.append(tpl.format(v=_format(v)))
#    1269
#    1270         return fmt_values
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _format(x)
#    1237                 return self.na_rep
#    1238             elif isinstance(x, PandasObject):
# -> 1239                 return "{x}".format(x=x)
#    1240             else:
#    1241                 # object dtype
#
# ... last 8 frames repeated, from the frame below ...
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __repr__(self)
#    1363         show_dimensions = get_option("display.show_dimensions")
#    1364
# -> 1365         self.to_string(
#    1366             buf=buf,
#    1367             name=self.name,
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
helsinki_places.remove({'type':'design_studio'})
# Out:
# <ipython-input-271-b357cc927e73>:1: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   helsinki_places.remove({'type':'design_studio'})
# {'n': 88, 'ok': 1.0}
