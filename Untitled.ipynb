# %%
from dotenv import load_dotenv
import src.query as query
import src.folium as fl
from pymongo import GEOSPHERE
import pandas as pd

from pymongo import MongoClient

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
load_dotenv('.env')
# Out:
# True

# %% [markdown]
# Connection to MongoDB database 'Ironhack'

# %%
conn = MongoClient("localhost:27017")
db = conn.get_database("ironhack")

# %%
db.list_collection_names()
# Out:
# ['companies', 'restaurants', 'countries_small']

# %% [markdown]
# Here we create new collection called 'offices'

# %%
offices = db['offices']

# %% [markdown]
# These are the coordinates for our selected city: **Helsinki**

# %%
city_lat = 60.168377
city_lon =  24.935820
radius = 10000

# %% [markdown]
# Load tokens for Foursquare queries

# %%
client_id = os.getenv("FOURSQUARE_CLIENT_ID")
client_secret = os.getenv("FOURSQUARE_CLIENT_SECRET")

# %% [markdown]
# All coworking spaces as list of initial candidates

# %%
data = query.foursquare_query(city_lat, city_lon, 'coworking_space', radius, client_id, client_secret)

# %%
candidates = query.read_foursquare_response(data)

# %% [markdown]
# Let's insert them to our brand new collection in MongoDb

# %%
x = offices.insert_many(candidates)

# %% [markdown]
# Let's create the Point for each office

# %%
offices.find_one()
# Out:
# {'_id': ObjectId('5faec5cc7643f500c398cc4f'),
#  'name': 'Tiedekulma / Think Corner',
#  'location': {'coordinates': [24.948465, 60.169746], 'type': 'Point'}}

# %%
offices.create_index([('location', GEOSPHERE)])
# Out:
# 'location_2dsphere'

# %% [markdown]
# Now, let's plot the candidates

# %%
map_candidates = fl.create_map(city_lat, city_lon)

# %%
for candidate in candidates:
    lat = candidate['location']['coordinates'][1]
    lon = candidate['location']['coordinates'][0]
    
    fl.add_marker_icon(map_candidates, lat, lon, 'red','building','white',candidate['name'])

# %%
map_candidates
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's find tech start-ups in the city

# %%
data = query.foursquare_query(city_lat, city_lon, 'tech_startup', radius, client_id, client_secret)

# %% [markdown]
# Extract the data

# %%
tech_companies_list = query.read_foursquare_response(data)

# %% [markdown]
# Create collection

# %%
tech_companies = db['tech_companies']

# %%
x = tech_companies.insert_many(tech_companies_list)

# %%
tech_companies.create_index([('location', GEOSPHERE)])
# Out:
# 'location_2dsphere'

# %% [markdown]
# Now, let's find matches

# %%
query.find_matches_points(offices, tech_companies, 1, 'tech_startups_num')

# %%
df = pd.DataFrame(offices.find())

# %%
df
# Out:
#                          _id                       name  \
# 0   5faec5cc7643f500c398cc4f  Tiedekulma / Think Corner
# 1   5faec5cc7643f500c398cc50          Spalt PR Helsinki
# 2   5faec5cc7643f500c398cc51              Svensk Ungdom
# 3   5faec5cc7643f500c398cc52                  p2s Media
# 4   5faec5cc7643f500c398cc53              E28 Community
# ..                       ...                        ...
# 64  5faec5cc7643f500c398cc8f                Talent Base
# 65  5faec5cc7643f500c398cc90                 Hippostalo
# 66  5faec5cc7643f500c398cc91      Nuortenosasto Pointti
# 67  5faec5cc7643f500c398cc92         Ahti Business Park
# 68  5faec5cc7643f500c398cc93              Playmysong HQ
#
#                                              location  tech_startups_num
# 0   {'coordinates': [24.948465, 60.169746], 'type'...                 26
# 1   {'coordinates': [24.95028953736944, 60.1678398...                 26
# ...

# %%
###### Now find starbucks

# %%
data = query.foursquare_query(city_lat, city_lon, 'starbucks', radius, client_id, client_secret)

# %%
data
# Out:
# {'meta': {'code': 400,
#   'errorType': 'param_error',
#   'errorDetail': 'Invalid categoryId 556f676fbd6a75a99038d8ec',
#   'requestId': '5faed8ca71cf8433225af049'},
#  'response': {}}

# %%
starbucks = query.read_foursquare_response(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-213-451b67c008f2> in <module>
# ----> 1 starbucks = query.read_foursquare_response(data)
#
# ~/ironhack/IronHack-Project4-GeoSpatialProject/src/query.py in read_foursquare_response(data)
#      41 def read_foursquare_response(data):
#      42
# ---> 43     places = data['response']['groups'][0]['items']
#      44
#      45     temp_list = []
#
# KeyError: 'groups'

# %%
google_api = os.getenv("GOOGLE_PLACES")

# %%
google_api
# Out:
# 'AIzaSyCjpTLOy22RzTktQ13IGJ1iot9u50E7LoE'

# %%
a = query.google_places('Starbucks', 'AIzaSyDWhcKrN1tBWYhK8LqCcKP8RmBJYhw0_yo', 500,city_lat, city_long)

# %%
a
# Out:
# {'candidates': [{'geometry': {'location': {'lat': 60.16927620000001,
#      'lng': 24.93343},
#     'viewport': {'northeast': {'lat': 60.17060987989273,
#       'lng': 24.93483222989272},
#      'southwest': {'lat': 60.16791022010729, 'lng': 24.93213257010728}}},
#    'name': 'Starbucks Kamppi, Helsinki'}],
#  'status': 'OK'}
